# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
path=os.getcwd()+"\\filtered3.csv"
raw_data=pd.read_csv(path)
area=input("Enter area : ")
low=(int)(input("Min. budget : "))
high=(int)(input("Max. budget : "))
bhk=(int)(input("No. of BHK : "))
parking=(int)(input("Parking : "))
data=raw_data.loc[raw_data['AREA'] == area]
e_data=data[(data["Estimate"]>=low) & (data["Estimate"]<=high)]
print(e_data)
r_data=e_data[e_data["N_ROOM"]==bhk]
print(r_data)
# Out:
# Enter area : Chrompet
# Min. budget : 2000000
# Max. budget : 5000000
# No. of BHK : 2
# Parking : 1
#       PRT_ID      AREA  INT_SQFT  DIST_MAINROAD  N_ROOM  PARK_FACIL  Estimate
# 0     P05996  Chrompet       958            185       3           0   2032600
# 13    P08959  Chrompet       832             67       3           0   2328870
# 16    P01394  Chrompet      1122             42       3           0   2643060
# 20    P01853  Chrompet      1030            145       3           1   2498130
# 29    P08467  Chrompet      1021             18       3           1   4046510
# 31    P05942  Chrompet      1030            101       3           0   2143380
# 32    P03989  Chrompet       906            112       3           0   2129700
# 45    P01359  Chrompet       776            109       2           0   2555940
# 46    P07090  Chrompet      1257             22       4           1   4589890
# 52    P08441  Chrompet      1070            141       3           1   2566300
# ...

# %%
my=r_data.sort_values("PARK_FACIL",ascending=False)

# %%
my
# Out:
#       PRT_ID      AREA  INT_SQFT  DIST_MAINROAD  N_ROOM  PARK_FACIL  Estimate
# 1197  P08470  Chrompet       784              6       2           1   3325260
# 1573  P04918  Chrompet       754             38       2           1   3208080
# 1986  P08551  Chrompet       771            190       2           1   2629900
# 1337  P07298  Chrompet       734            191       2           1   2107350
# 58    P01409  Chrompet       743            175       2           1   3551780
# 1448  P01717  Chrompet       754             72       2           1   3163150
# 1060  P08403  Chrompet       771             72       2           1   2521700
# 1806  P02869  Chrompet       757             89       2           1   2539750
# 449   P03580  Chrompet       706             70       2           1   3145680
# 346   P08297  Chrompet       722             26       2           1   2869800
# 891   P04773  Chrompet       703             61       2           1   2455740
# ...
